# %% [markdown]
# ## 1. Imports and Setup

# %%
import pandas as pd
import numpy as np
import json
pd.set_option('display.max_columns', None)

# %%
#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

# %%
folder_path = 'toni_data_2609/'

# %% [markdown]
# ## 2. Politicians DF - Data Cleaning

# %%
politicians = pd.read_csv(f'{folder_path}politicians.csv')
print(len(politicians))

fractions = pd.read_pickle(f'{folder_path}factions.pkl')
fractions.head(40)

party = fractions[['id', 'abbreviation']].drop_duplicates()
party.head(20)

politicians = pd.merge(politicians, party, left_on='faction_id', right_on='id', how='left')

# removing duplicates
print(len(politicians))
politicians = politicians.drop_duplicates()
print(len(politicians))

# Remove duplications: keep one name if namechange (marriage), keep only longest academic title if multiple, keep only one faction if multiple
# Step 1: Function to consolidate values, including longest title, actual faction, institution name, and name streamlining
def consolidate_group(group):
    # 1. Longest academic title
    longest_title_idx = group['academic_title'].dropna().str.len().idxmax() if not group['academic_title'].dropna().empty else None
    if longest_title_idx is not None:
        longest_title = group.loc[longest_title_idx, 'academic_title']
        group['academic_title'] = group['academic_title'].fillna(longest_title)  # Fill if we found a valid longest title

    # 2. Faction: prefer entries with a valid faction (i.e., non-null faction_id and non-Fraktionslos)
    valid_faction = group.loc[group['faction_id'].notnull() & (group['abbreviation'] != 'Fraktionslos')]
    if not valid_faction.empty:
        valid_faction_row = valid_faction.iloc[0]  # Take the first valid faction row
        group['faction_id'] = group['faction_id'].fillna(valid_faction_row['faction_id'])
        group['abbreviation'] = group['abbreviation'].fillna(valid_faction_row['abbreviation'])
        group['institution_name'] = group['institution_name'].fillna(valid_faction_row['institution_name'])

    # 3. Streamline names: prioritize the most recent last name and first name
    most_recent_entry = group.iloc[-1]  # Take the most recent entry as the baseline for names
    group['last_name'] = group['last_name'].fillna(most_recent_entry['last_name'])
    group['first_name'] = group['first_name'].fillna(most_recent_entry['first_name'])

    return group

# Step 2: Apply the function, grouping by both 'ui' and 'electoral_term'
politicians = politicians.groupby(['ui', 'electoral_term']).apply(consolidate_group)

# Optional: Reset index if needed
politicians.reset_index(drop=True, inplace=True)

# Step 3: Drop duplicates within each group, keeping the relevant rows
politicians = politicians.drop_duplicates(subset=['ui', 'electoral_term'], keep='first')

unique_combinations = politicians[['ui', 'electoral_term']].drop_duplicates()
print('unique politicians after dupl removal:', len(unique_combinations))

politicians.sample(10)
# Out:
# 19632
# 19632
# 18873
# unique politicians after dupl removal: 12492
#              ui  electoral_term  faction_id  first_name      last_name  \
# 2593   11000695              10          25       Horst       Gobrecht
# 6805   11001852               4          25       Fritz  Rinderspacher
# 11823  11003574              18           5      Günter         Krings
# 16880  11004969              19           4      Marcel       Emmerich
# 17643  11005108              20          25      Annika          Klose
# 3521   11000960               8           5  Karl Heinz       Hornhues
# 13955  11004168              19           5      Dieter          Stier
# 10080  11002682              17          25       Frank        Hofmann
# 79     11000022              13          15         Ina       Albowitz
# 6522   11001761               2          25      Werner          Pusch
#
#                  birth_place birth_country  birth_date  death_date    gender  \
# 2593                 Hamburg   Deutschland  19.11.1936  26.01.2015  männlich
# 6805              Hugsweiler   Deutschland  15.11.1909  08.07.1998  männlich
# 11823                 Rheydt   Deutschland  07.08.1969          -1  männlich
# 16880             Reutlingen   Deutschland  12.05.1991          -1  männlich
# 17643               Dortmund   Deutschland  24.06.1992          -1  weiblich
# 3521   Stadtlohn / Westfalen   Deutschland  10.06.1939          -1  männlich
# 13955             Weißenfels   Deutschland  29.06.1964          -1  männlich
# 10080            Schweinfurt   Deutschland  21.04.1949          -1  männlich
# 79        Weimar / Thüringen   Deutschland  26.04.1943          -1  weiblich
# 6522                 Templin   Deutschland  17.08.1913  16.09.1988  männlich
#
#                                               profession constituency  \
# 2593                                       Steuerberater          NaN
# 6805                                Oberstudienrat i. R.          NaN
# 11823                                             Jurist          NaN
# 16880                        Wissenschaftlicher Referent          NaN
# 17643                            Sozialwissenschaftlerin          NaN
# 3521                                     Dipl.-Volkswirt          NaN
# 13955  Zootechniker/Mechanisator, Dipl.-Ing.agr., Pfe...          NaN
# 10080             Kriminaloberrat a. D., Diplomvolkswirt      Volkach
# 79                               Werbekauffrau, Hausfrau          NaN
# 6522                               Studienassessor a. D.          NaN
#
#       aristocracy academic_title institution_type  \
# 2593          NaN            NaN  Fraktion/Gruppe
# 6805          NaN            Dr.  Fraktion/Gruppe
# 11823         NaN            Dr.  Fraktion/Gruppe
# 16880         NaN            NaN  Fraktion/Gruppe
# 17643         NaN            NaN  Fraktion/Gruppe
# 3521          NaN      Prof. Dr.  Fraktion/Gruppe
# 13955         NaN            NaN  Fraktion/Gruppe
# 10080         NaN            NaN  Fraktion/Gruppe
# 79            NaN            NaN  Fraktion/Gruppe
# 6522          NaN            NaN  Fraktion/Gruppe
#
#                                         institution_name    id  \
# 2593   Fraktion der Sozialdemokratischen Partei Deuts...  25.0
# 6805   Fraktion der Sozialdemokratischen Partei Deuts...  25.0
# 11823  Fraktion der Christlich Demokratischen Union/C...   5.0
# 16880                     Fraktion BÜNDNIS 90/DIE GRÜNEN   4.0
# 17643  Fraktion der Sozialdemokratischen Partei Deuts...  25.0
# 3521   Fraktion der Christlich Demokratischen Union/C...   5.0
# 13955  Fraktion der Christlich Demokratischen Union/C...   5.0
# 10080  Fraktion der Sozialdemokratischen Partei Deuts...  25.0
# 79             Fraktion der Freien Demokratischen Partei  15.0
# 6522   Fraktion der Sozialdemokratischen Partei Deuts...  25.0
#
#                 abbreviation
# 2593                     SPD
# 6805                     SPD
# 11823                CDU/CSU
# 16880  Bündnis 90/Die Grünen
# 17643                    SPD
# 3521                 CDU/CSU
# 13955                CDU/CSU
# 10080                    SPD
# 79                       FDP
# 6522                     SPD

# %% [markdown]
# ## 3. Speech DF - Data Cleaning

# %%
speech_content = pd.read_pickle(f'{folder_path}speech_content.pkl')
speech_content['date'] = pd.to_datetime(speech_content['date'], unit='s')

# Standardize first_name and last_name by stripping whitespace and converting to lowercase
speech_content['first_name'] = speech_content['first_name'].str.strip().str.lower()
speech_content['last_name'] = speech_content['last_name'].str.strip().str.lower()

# Step 2: Find the most frequent politician_id for each combination of first_name, last_name, and electoral_term
politician_id_counts = speech_content.groupby(['first_name', 'last_name', 'electoral_term', 'politician_id']).size().reset_index(name='count')

# Find the most frequent politician_id for each first_name, last_name, and electoral_term
most_frequent_id = politician_id_counts.loc[politician_id_counts.groupby(['first_name', 'last_name', 'electoral_term'])['count'].idxmax()]

# Step 3: Merge the most frequent politician_id back into the speech_content DataFrame
corrected_speech_content = speech_content.merge(most_frequent_id[['first_name', 'last_name', 'electoral_term', 'politician_id']], 
                                                on=['first_name', 'last_name', 'electoral_term'], how='left', suffixes=('', '_canonical'))

# Step 4: Replace all politician_ids with the canonical (most frequent) politician_id
corrected_speech_content['politician_id'] = corrected_speech_content['politician_id_canonical']

# Step 5: Drop unnecessary columns
corrected_speech_content.drop(columns=['politician_id_canonical'], inplace=True)

# Step 6: Check for remaining invalid politician_ids
# show remaining politicians with id -1 and examine
invalid_politicians = corrected_speech_content[corrected_speech_content['politician_id']==-1]
print(len(invalid_politicians))
#invalid_politicians.to_excel('invalid_politicians.xlsx')

# if politicians id is -1, I want to match with the politician id from the politicians table based on first and last name
politicians['first_name'] = politicians['first_name'].str.lower()
politicians['last_name'] = politicians['last_name'].str.lower()

# merge speech with politicians
name_merge = pd.merge(
    corrected_speech_content, 
    politicians[['first_name', 'last_name', 'ui']], 
    on=['first_name', 'last_name'], 
    how='left',
    suffixes=('', '_politician'))

name_merge['politician_id'] = name_merge.apply(
    lambda row: row['ui'] if row['politician_id'] == -1 else row['politician_id'], 
    axis=1
)

corrected_speech_content_updated = name_merge.drop(columns=['ui'])

corrected_speech_content_updated.head()

# change all rows where first_name = thomas maizi and last_name = re to politician_id = 11004105
corrected_speech_content_updated.loc[(corrected_speech_content_updated['first_name'] == 'thomas') & (corrected_speech_content_updated['last_name'] == 're'), 'politician_id'] = 11004105

# show remaining politicians with id -1 of id NaN and examine
invalid_politicians_v2 = corrected_speech_content_updated[(corrected_speech_content_updated['politician_id']==-1)|(corrected_speech_content_updated['politician_id'].isnull())]
print(len(invalid_politicians_v2))
#invalid_politicians_v2.to_excel('invalid_politicians_v2.xlsx')

# The data seems to be more complete now. In the period of interest, only some values remain missing.
# Out:
# 39196
# 33221

# %% [markdown]
# ## 4. Merging DFs

# %%
# Step 7: Merge corrected_speech_content with politicians DataFrame
# Ensure the politicians DataFrame is loaded and standardized similarly
politicians = politicians[['ui', 'electoral_term', 'faction_id', 'abbreviation', 'first_name', 'last_name', 'birth_place', 'birth_country',
                           'birth_date', 'death_date', 'gender', 'profession', 'academic_title', 'institution_type', 'institution_name']]

politicians['first_name'] = politicians['first_name'].str.strip().str.lower()
politicians['last_name'] = politicians['last_name'].str.strip().str.lower()


# Perform the merge
datacube = corrected_speech_content_updated.merge(politicians, left_on=['politician_id', 'electoral_term'], 
                                          right_on=['ui', 'electoral_term'], how='left')


# Count matches and entries without politician information after the merge
matches = datacube['ui'].notnull().sum()
remaining_without_politician_info = datacube['ui'].isnull().sum()

# Output results
print(f"Total matches found: {matches}")
print(f"Total speech entries without politician information: {remaining_without_politician_info}")
datacube.head()
# Out:
# Total matches found: 2761202
# Total speech entries without politician information: 36285
#    id  electoral_term  session first_name_x  \
# 0   0               1        2
# 1   1               1        2
# 2   2               1        2
# 3   3               1        2
# 4   4               1        2
#
#                                         document_url last_name_x  \
# 0  https://dip21.bundestag.de/dip21/btp/01/01002.pdf      köhler
# 1  https://dip21.bundestag.de/dip21/btp/01/01002.pdf      arnold
# 2  https://dip21.bundestag.de/dip21/btp/01/01002.pdf      köhler
# 3  https://dip21.bundestag.de/dip21/btp/01/01002.pdf       heuss
# 4  https://dip21.bundestag.de/dip21/btp/01/01002.pdf      köhler
#
#    faction_id_x           position_short             position_long  \
# 0            -1  Presidium of Parliament                 präsident
# 1            -1                    Guest  präsident des bundesrats
# 2            -1  Presidium of Parliament                 präsident
# 3            -1                    Guest           bundespräsident
# 4            -1  Presidium of Parliament                 präsident
#
#    politician_id                                     speech_content  \
# 0     11001150.0  Meine Damen und Herren! Ich eröffne die 2. Sit...
# 1     11000053.0    Der Bundesrat ist versammelt, Herr Präsident.\n
# 2     11001150.0  Ich danke für diese Erklärung. Ich stelle dami...
# 3            NaN                         Ja, ich habe den Wunsch.\n
# 4     11001150.0  Ich erteile dem Herrn Bundespräsidenten das Wo...
#
#                  date          ui  faction_id_y abbreviation first_name_y  \
# 0 1949-09-11 21:00:00  11001150.0           5.0      CDU/CSU        erich
# 1 1949-09-11 21:00:00  11000053.0          28.0            Z         thea
# 2 1949-09-11 21:00:00  11001150.0           5.0      CDU/CSU        erich
# 3 1949-09-11 21:00:00         NaN           NaN          NaN          NaN
# 4 1949-09-11 21:00:00  11001150.0           5.0      CDU/CSU        erich
#
#   last_name_y birth_place birth_country  birth_date  death_date    gender  \
# 0      köhler      Erfurt   Deutschland  27.06.1892  23.10.1958  männlich
# 1      arnold       Fulda   Deutschland  11.12.1882  26.01.1966  weiblich
# 2      köhler      Erfurt   Deutschland  27.06.1892  23.10.1958  männlich
# 3         NaN         NaN           NaN         NaN         NaN       NaN
# 4      köhler      Erfurt   Deutschland  27.06.1892  23.10.1958  männlich
#
#                                           profession academic_title  \
# 0  Präsident DBT a.D., Wirtschaftsberater, Volkswirt            Dr.
# 1                                     Rektorin a. D.            NaN
# 2  Präsident DBT a.D., Wirtschaftsberater, Volkswirt            Dr.
# 3                                                NaN            NaN
# 4  Präsident DBT a.D., Wirtschaftsberater, Volkswirt            Dr.
#
#   institution_type                                   institution_name
# 0  Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 1  Fraktion/Gruppe                  Fraktion Deutsche Zentrums-Partei
# 2  Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 3              NaN                                                NaN
# 4  Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...

# %%
# Perform merge on ui only (without electoral term for completeness)
# Identify rows where the merge failed
failed_merge = datacube['ui'].isna()

# Step 4: Perform a fallback merge based on ids only without electoral term
datacube_fallback = corrected_speech_content_updated[failed_merge].merge(
    politicians, 
    left_on=['politician_id'], 
    right_on=['ui'], 
    how='left',
    suffixes=('', '_politician_fallback')
)

datacube.update(datacube_fallback)

datacube.head()
# Out:
#     id  electoral_term  session first_name_x  \
# 0    3               1        2
# 1    5               1        2
# 2   23               1        5
# 3   36               1        5
# 4  260               1       10
#
#                                         document_url last_name_x  \
# 0  https://dip21.bundestag.de/dip21/btp/01/01002.pdf      köhler
# 1  https://dip21.bundestag.de/dip21/btp/01/01002.pdf      arnold
# 2  https://dip21.bundestag.de/dip21/btp/01/01005.pdf      köhler
# 3  https://dip21.bundestag.de/dip21/btp/01/01005.pdf       heuss
# 4  https://dip21.bundestag.de/dip21/btp/01/01010.pdf      köhler
#
#    faction_id_x        position_short  \
# 0            -1                 Guest
# 1            -1                 Guest
# 2            -1            Chancellor
# 3            -1              Minister
# 4            -1  Member of Parliament
#
#                                      position_long  politician_id  \
# 0                                  bundespräsident     11001150.0
# 1                                  bundespräsident     11000053.0
# 2                                                      11001150.0
# 3  bundesminister für landwirtschaft und ernährung            NaN
# 4                                                      11001150.0
#
#                                       speech_content                date  \
# 0                         Ja, ich habe den Wunsch.\n 1949-09-11 21:00:00
# 1  Verehrte Mitglieder des Bundestags, des Bundes... 1949-09-11 21:00:00
# 2                                                    1949-09-19 21:00:00
# 3          Ich schwöre es, so wahr mir Gott helfe.\n 1949-09-19 21:00:00
# 4  Meine Damen und Herren! Bitte, betrachten Sie ... 1949-09-28 21:00:00
#
#            ui  faction_id_y abbreviation first_name_y last_name_y birth_place  \
# 0  11001150.0           5.0      CDU/CSU        erich      köhler      Erfurt
# 1  11000053.0          28.0            Z         thea      arnold       Fulda
# 2  11001150.0           5.0      CDU/CSU        erich      köhler      Erfurt
# 3         NaN           NaN          NaN          NaN         NaN         NaN
# 4  11001150.0           5.0      CDU/CSU        erich      köhler      Erfurt
#
#   birth_country  birth_date  death_date    gender  \
# 0   Deutschland  27.06.1892  23.10.1958  männlich
# 1   Deutschland  11.12.1882  26.01.1966  weiblich
# 2   Deutschland  27.06.1892  23.10.1958  männlich
# 3           NaN         NaN         NaN       NaN
# 4   Deutschland  27.06.1892  23.10.1958  männlich
#
#                                           profession academic_title  \
# 0  Präsident DBT a.D., Wirtschaftsberater, Volkswirt            Dr.
# 1                                     Rektorin a. D.            NaN
# 2  Präsident DBT a.D., Wirtschaftsberater, Volkswirt            Dr.
# 3                                                NaN            NaN
# 4  Präsident DBT a.D., Wirtschaftsberater, Volkswirt            Dr.
#
#   institution_type                                   institution_name
# 0  Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 1  Fraktion/Gruppe                  Fraktion Deutsche Zentrums-Partei
# 2  Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 3              NaN                                                NaN
# 4  Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...

# %%
remaining_without_politician_info = datacube['ui'].isnull().sum()
remaining_without_politician_info
# Out:
# 36103

# %% [markdown]
# ### 4.1 Remove Duplicates

# %%
print(len(datacube))  # Print the length before dropping duplicates

# Drop exact duplicates without inplace (so you can assign the result to a new variable)
datacube_nodup = datacube.drop_duplicates(subset=['id', 'speech_content', 'politician_id'], inplace=False)

print(len(datacube_nodup))  # Print the length after dropping duplicates

# Display the first few rows of the cleaned data
datacube_nodup.head()
# Out:
# 2797487
# 959795
#     id  electoral_term  session first_name_x  \
# 0    3               1        2
# 1    5               1        2
# 2   23               1        5
# 3   36               1        5
# 4  260               1       10
#
#                                         document_url last_name_x  \
# 0  https://dip21.bundestag.de/dip21/btp/01/01002.pdf      köhler
# 1  https://dip21.bundestag.de/dip21/btp/01/01002.pdf      arnold
# 2  https://dip21.bundestag.de/dip21/btp/01/01005.pdf      köhler
# 3  https://dip21.bundestag.de/dip21/btp/01/01005.pdf       heuss
# 4  https://dip21.bundestag.de/dip21/btp/01/01010.pdf      köhler
#
#    faction_id_x        position_short  \
# 0            -1                 Guest
# 1            -1                 Guest
# 2            -1            Chancellor
# 3            -1              Minister
# 4            -1  Member of Parliament
#
#                                      position_long  politician_id  \
# 0                                  bundespräsident     11001150.0
# 1                                  bundespräsident     11000053.0
# 2                                                      11001150.0
# 3  bundesminister für landwirtschaft und ernährung            NaN
# 4                                                      11001150.0
#
#                                       speech_content                date  \
# 0                         Ja, ich habe den Wunsch.\n 1949-09-11 21:00:00
# 1  Verehrte Mitglieder des Bundestags, des Bundes... 1949-09-11 21:00:00
# 2                                                    1949-09-19 21:00:00
# 3          Ich schwöre es, so wahr mir Gott helfe.\n 1949-09-19 21:00:00
# 4  Meine Damen und Herren! Bitte, betrachten Sie ... 1949-09-28 21:00:00
#
#            ui  faction_id_y abbreviation first_name_y last_name_y birth_place  \
# 0  11001150.0           5.0      CDU/CSU        erich      köhler      Erfurt
# 1  11000053.0          28.0            Z         thea      arnold       Fulda
# 2  11001150.0           5.0      CDU/CSU        erich      köhler      Erfurt
# 3         NaN           NaN          NaN          NaN         NaN         NaN
# 4  11001150.0           5.0      CDU/CSU        erich      köhler      Erfurt
#
#   birth_country  birth_date  death_date    gender  \
# 0   Deutschland  27.06.1892  23.10.1958  männlich
# 1   Deutschland  11.12.1882  26.01.1966  weiblich
# 2   Deutschland  27.06.1892  23.10.1958  männlich
# 3           NaN         NaN         NaN       NaN
# 4   Deutschland  27.06.1892  23.10.1958  männlich
#
#                                           profession academic_title  \
# 0  Präsident DBT a.D., Wirtschaftsberater, Volkswirt            Dr.
# 1                                     Rektorin a. D.            NaN
# 2  Präsident DBT a.D., Wirtschaftsberater, Volkswirt            Dr.
# 3                                                NaN            NaN
# 4  Präsident DBT a.D., Wirtschaftsberater, Volkswirt            Dr.
#
#   institution_type                                   institution_name
# 0  Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 1  Fraktion/Gruppe                  Fraktion Deutsche Zentrums-Partei
# 2  Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 3              NaN                                                NaN
# 4  Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...

# %% [markdown]
# ### 4.2 Distinguish Period

# %%
# Step 8: Filter for electoral terms 17, 18, 19 and 20 and prepare the final datacube
datacube_period = datacube_nodup[datacube_nodup['electoral_term'].isin([17, 18, 19, 20])]
datacube_period = datacube_period[['id', 'electoral_term', 'session', 
                     'first_name_x', 'last_name_x', 'faction_id_x', 'politician_id', 'ui',
                     'position_short', 'position_long', 
                     'speech_content', 'date']]

# %%
# Clean DF

empty_or_whitespace_mask = datacube_period['speech_content'].str.strip() == ''
datacube_period = datacube_period[~empty_or_whitespace_mask]

# Step 7: Count matches and entries without politician information after the merge
matches = datacube_period['ui'].notnull().sum()
remaining_without_politician_info = datacube_period['ui'].isnull().sum()

# Output results
print(f"Total matches found: {matches}")
print(f"Total speech entries without politician information: {remaining_without_politician_info}")
# Out:
# Total matches found: 237396
# Total speech entries without politician information: 732

# %%
# Examine whether there are potential different ids in the datacube for the same first and last name and show the politician_id	first_name	last_name	politician_id_matched
# Group by first_name and last_name, and filter groups that have more than one unique 'ui'
duplicate_politicians = datacube_period.groupby(['first_name_x', 'last_name_x']).filter(lambda x: x['ui'].nunique() > 1)

# Display the politicians with the same first and last name but different 'ui'
duplicate_politicians_sorted = duplicate_politicians.sort_values(by=['first_name_x', 'last_name_x'])

# export duplicate_politicians_sorted to excel
duplicate_politicians_sorted.to_excel('duplicate_politicians_sorted.xlsx')

# Show the result
duplicate_politicians_sorted.head()
# Out:
#            id  electoral_term  session first_name_x last_name_x  faction_id_x  \
# 32816  749023              17       83                 adenauer            -1
# 32829  749052              17       83                 adenauer            -1
# 32831  749473              17       84                 adenauer            -1
# 32833  751424              17       91                 adenauer            -1
# 32852  756606              17      112                 adenauer            -1
#
#        politician_id          ui           position_short  \
# 32816     11000009.0  11000009.0                 Minister
# 32829     11000009.0  11000009.0                 Minister
# 32831     11000009.0  11000009.0     Member of Parliament
# 32833     11000009.0  11000009.0  Presidium of Parliament
# 32852     11000009.0  11000009.0                    Guest
#
#                    position_long  \
# 32816  bundesminister des innern
# 32829  bundesminister des innern
# 32831
# 32833            vizepräsidentin
# 32852           senator (berlin)
#
#                                           speech_content                date
# 32816  \nHerr Abgeordneter, der Migrationsbericht, de... 2011-01-18 22:00:00
# 32829  Bundesminister Dr. Thomas de Maizière\n\nnoch ... 2011-01-18 22:00:00
# 32831  Nein, ich würde das gern erst ausführen. Er ka... 2011-01-19 22:00:00
# 32833  Ausschuss für Umwelt, Naturschutz und Reaktors... 2011-02-10 22:00:00
# 32852  Frau Paus, erstens hat der Senat, um das noch ... 2011-05-26 21:00:00

# %%
# show me the entries where id appears more than one time
datacube_nodup[datacube_nodup['id'].duplicated(keep=False)].sort_values('id').tail(20)
# Out:
#               id  electoral_term  session first_name_x  \
# 2777794  1113881              20       72         sven
# 37641    1113881              20       72
# 2778118  1114003              20       86         sven
# 37642    1114003              20       86
# 2778126  1114005              20       86         sven
# 37643    1114005              20       86
# 2778134  1114007              20       86         sven
# 37644    1114007              20       86
# 37645    1114012              20       86
# 2778159  1114012              20       86         sven
# 2778167  1114014              20       86         sven
# 37646    1114014              20       86
# 2786453  1116593              20       21      andreas
# 39569    1116593              20       21
# 2786455  1116595              20       21      andreas
# 39570    1116595              20       21
# 2786457  1116597              20       21      andreas
# 39571    1116597              20       21
# 39761    1119943              20       11
# 2796320  1119943              20       11       katrin
#
#                                               document_url    last_name_x  \
# 2777794  https://dip21.bundestag.de/dip21/btp/20/20072.pdf        schulze
# 37641    https://dip21.bundestag.de/dip21/btp/20/20072.pdf         hauffe
# 2778118  https://dip21.bundestag.de/dip21/btp/20/20086.pdf        schulze
# 37642    https://dip21.bundestag.de/dip21/btp/20/20086.pdf      schneider
# 2778126  https://dip21.bundestag.de/dip21/btp/20/20086.pdf        schulze
# 37643    https://dip21.bundestag.de/dip21/btp/20/20086.pdf           will
# 2778134  https://dip21.bundestag.de/dip21/btp/20/20086.pdf        schulze
# 37644    https://dip21.bundestag.de/dip21/btp/20/20086.pdf         schmid
# 37645    https://dip21.bundestag.de/dip21/btp/20/20086.pdf        stierle
# 2778159  https://dip21.bundestag.de/dip21/btp/20/20086.pdf        schulze
# 2778167  https://dip21.bundestag.de/dip21/btp/20/20086.pdf        schulze
# 37646    https://dip21.bundestag.de/dip21/btp/20/20086.pdf         schmid
# 2786453  https://dip21.bundestag.de/dip21/btp/20/20021.pdf   bovenschulte
# 39569    https://dip21.bundestag.de/dip21/btp/20/20021.pdf   gerstenmaier
# 2786455  https://dip21.bundestag.de/dip21/btp/20/20021.pdf   bovenschulte
# 39570    https://dip21.bundestag.de/dip21/btp/20/20021.pdf         storch
# 2786457  https://dip21.bundestag.de/dip21/btp/20/20021.pdf   bovenschulte
# 39571    https://dip21.bundestag.de/dip21/btp/20/20021.pdf   gerstenmaler
# 39761    https://dip21.bundestag.de/dip21/btp/20/20011.pdf         jaeger
# 2796320  https://dip21.bundestag.de/dip21/btp/20/20011.pdf  göring-eckard
#
#          faction_id_x           position_short  \
# 2777794            -1                 Minister
# 37641              25                 Minister
# 2778118            -1                 Minister
# 37642              -1                 Minister
# 2778126            -1                 Minister
# 37643              15                 Minister
# 2778134            -1                 Minister
# 37644              -1                 Minister
# 37645              25                 Minister
# 2778159            -1                 Minister
# 2778167            -1                 Minister
# 37646              -1                 Minister
# 2786453            -1                Not found
# 39569              -1                Not found
# 2786455            -1                Not found
# 39570              -1                Not found
# 2786457            -1                Not found
# 39571              -1                Not found
# 39761              -1  Presidium of Parliament
# 2796320            -1  Presidium of Parliament
#
#                                              position_long  politician_id  \
# 2777794  Minister                                     (...            NaN
# 37641    Minister                                     (...     11000829.0
# 2778118  Minister                                     (...            NaN
# 37642    Minister                                     (...     11002046.0
# 2778126  Minister                                     (...            NaN
# 37643    Minister                                     (...     11002514.0
# 2778134  Minister                                     (...            NaN
# 37644    Minister                                     (...     11001993.0
# 37645    Minister                                     (...     11002250.0
# 2778159  Minister                                     (...            NaN
# 2778167  Minister                                     (...            NaN
# 37646    Minister                                     (...     11001993.0
# 2786453                                               None            NaN
# 39569                                            präsident     11000669.0
# 2786455                                               None            NaN
# 39570                            bundesminister für arbeit     11002264.0
# 2786457                                               None            NaN
# 39571                                            präsident     11000669.0
# 39761                                      Vizepräsidentin     11001006.0
# 2796320                                    Vizepräsidentin            NaN
#
#                                             speech_content       date  \
# 2777794  \n\nSelbstverständlich. Zwei Minuten habe ich ... 2022-11-30
# 37641    \n\nSelbstverständlich. Zwei Minuten habe ich ... 2022-11-30
# 2778118  \n\nSehr geehrte Frau Präsidentin! Sehr geehrt... 2023-02-10
# 37642    \n\nSehr geehrte Frau Präsidentin! Sehr geehrt... 2023-02-10
# 2778126                                            \n\nJa. 2023-02-10
# 37643                                              \n\nJa. 2023-02-10
# 2778134  \n\nJa, gestatte ich. Ich möchte bloß noch den... 2023-02-10
# 37644    \n\nJa, gestatte ich. Ich möchte bloß noch den... 2023-02-10
# 37645    \n\nSie haben absolut recht: Das letzte Wort h... 2023-02-10
# 2778159  \n\nSie haben absolut recht: Das letzte Wort h... 2023-02-10
# 2778167  \n\nSo ist es. – Ich habe ja erwartet, dass es... 2023-02-10
# 37646    \n\nSo ist es. – Ich habe ja erwartet, dass es... 2023-02-10
# 2786453  \n\nSehr geehrte Frau Präsidentin! Meine sehr ... 2022-03-17
# 39569    \n\nSehr geehrte Frau Präsidentin! Meine sehr ... 2022-03-17
# 2786455  \n\nInsbesondere den Kollegen von der Union wa... 2022-03-17
# 39570    \n\nInsbesondere den Kollegen von der Union wa... 2022-03-17
# 2786457  \n\nDeshalb hoffe ich sehr, dass am Ende auch ... 2022-03-17
# 39571    \n\nDeshalb hoffe ich sehr, dass am Ende auch ... 2022-03-17
# 39761    \n\nFür die Fraktion Bündnis 90/Die Grünen hat... 2022-01-13
# 2796320  \n\nFür die Fraktion Bündnis 90/Die Grünen hat... 2022-01-13
#
#                  ui  faction_id_y abbreviation first_name_y   last_name_y  \
# 2777794         NaN           NaN          NaN          NaN           NaN
# 37641    11000829.0          25.0          SPD      herbert        hauffe
# 2778118         NaN           NaN          NaN          NaN           NaN
# 37642    11002046.0          15.0          FDP       ludwig     schneider
# 2778126         NaN           NaN          NaN          NaN           NaN
# 37643    11002514.0          15.0          FDP       rudolf          will
# 2778134         NaN           NaN          NaN          NaN           NaN
# 37644    11001993.0          25.0          SPD        carlo        schmid
# 37645    11002250.0          25.0          SPD        georg       stierle
# 2778159         NaN           NaN          NaN          NaN           NaN
# 2778167         NaN           NaN          NaN          NaN           NaN
# 37646    11001993.0          25.0          SPD        carlo        schmid
# 2786453         NaN           NaN          NaN          NaN           NaN
# 39569    11000669.0           5.0      CDU/CSU        eugen  gerstenmaier
# 2786455         NaN           NaN          NaN          NaN           NaN
# 39570    11002264.0           5.0      CDU/CSU        anton        storch
# 2786457         NaN           NaN          NaN          NaN           NaN
# 39571    11000669.0           5.0      CDU/CSU        eugen  gerstenmaier
# 39761    11001006.0           5.0      CDU/CSU      richard        jaeger
# 2796320         NaN           NaN          NaN          NaN           NaN
#
#                birth_place birth_country  birth_date  death_date    gender  \
# 2777794                NaN           NaN         NaN         NaN       NaN
# 37641               Bochum   Deutschland  18.02.1914  21.05.1997  männlich
# 2778118                NaN           NaN         NaN         NaN       NaN
# 37642            Erdhausen   Deutschland  20.09.1898  23.04.1978  männlich
# 2778126                NaN           NaN         NaN         NaN       NaN
# 37643              München   Deutschland  16.12.1893  10.01.1963  männlich
# 2778134                NaN           NaN         NaN         NaN       NaN
# 37644            Perpignan    Frankreich  03.12.1896  11.12.1979  männlich
# 37645       Frankfurt/Main   Deutschland  22.12.1897  26.05.1979  männlich
# 2778159                NaN           NaN         NaN         NaN       NaN
# 2778167                NaN           NaN         NaN         NaN       NaN
# 37646            Perpignan    Frankreich  03.12.1896  11.12.1979  männlich
# 2786453                NaN           NaN         NaN         NaN       NaN
# 39569     Kirchheim / Teck   Deutschland  25.08.1906  13.03.1986  männlich
# 2786455                NaN           NaN         NaN         NaN       NaN
# 39570                Fulda   Deutschland  01.04.1892  26.11.1975  männlich
# 2786457                NaN           NaN         NaN         NaN       NaN
# 39571     Kirchheim / Teck   Deutschland  25.08.1906  13.03.1986  männlich
# 39761    Berlin-Schöneberg   Deutschland  16.02.1913  15.05.1998  männlich
# 2796320                NaN           NaN         NaN         NaN       NaN
#
#                                                 profession academic_title  \
# 2777794                                                NaN            NaN
# 37641                                            Architekt            NaN
# 2778118                                                NaN            NaN
# 37642      Rechtsanwalt und Notar, Vizepräsident DBT a. D.            Dr.
# 2778126                                                NaN            NaN
# 37643                                Versicherungsdirektor            Dr.
# 2778134                                                NaN            NaN
# 37644    Vizepräsident DBT a. D., em. o. Universitätspr...            Dr.
# 37645                                             Kaufmann            NaN
# 2778159                                                NaN            NaN
# 2778167                                                NaN            NaN
# 37646    Vizepräsident DBT a. D., em. o. Universitätspr...            Dr.
# 2786453                                                NaN            NaN
# 39569    Präsident des Deutschen Bundestages, Oberkonsi...            Dr.
# 2786455                                                NaN            NaN
# 39570                                 Bundesminister a. D.            NaN
# 2786457                                                NaN            NaN
# 39571    Präsident des Deutschen Bundestages, Oberkonsi...            Dr.
# 39761        Bundesminister a. D., Vizepräsident DBT a. D.            Dr.
# 2796320                                                NaN            NaN
#
#         institution_type                                   institution_name
# 2777794              NaN                                                NaN
# 37641    Fraktion/Gruppe  Fraktion der Sozialdemokratischen Partei Deuts...
# 2778118              NaN                                                NaN
# 37642    Fraktion/Gruppe          Fraktion der Freien Demokratischen Partei
# 2778126              NaN                                                NaN
# 37643    Fraktion/Gruppe          Fraktion der Freien Demokratischen Partei
# 2778134              NaN                                                NaN
# 37644    Fraktion/Gruppe  Fraktion der Sozialdemokratischen Partei Deuts...
# 37645    Fraktion/Gruppe  Fraktion der Sozialdemokratischen Partei Deuts...
# 2778159              NaN                                                NaN
# 2778167              NaN                                                NaN
# 37646    Fraktion/Gruppe  Fraktion der Sozialdemokratischen Partei Deuts...
# 2786453              NaN                                                NaN
# 39569    Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 2786455              NaN                                                NaN
# 39570    Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 2786457              NaN                                                NaN
# 39571    Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 39761    Fraktion/Gruppe  Fraktion der Christlich Demokratischen Union/C...
# 2796320              NaN                                                NaN

# %%
datacube_nodup.dtypes
# Out:
# id                           int64
# electoral_term               int32
# session                      int32
# first_name_x                object
# document_url                object
# last_name_x                 object
# faction_id_x                 int64
# position_short              object
# position_long               object
# politician_id              float64
# speech_content              object
# date                datetime64[ns]
# ui                         float64
# faction_id_y               float64
# abbreviation                object
# first_name_y                object
# last_name_y                 object
# birth_place                 object
# birth_country               object
# birth_date                  object
# death_date                  object
# gender                      object
# profession                  object
# academic_title              object
# institution_type            object
# institution_name            object
# dtype: object

# %%
# Select 2022-02-16 and export as excel
datacube_period_2022_0216 = datacube_nodup[datacube_nodup['date'] == '2022-02-16']
datacube_period_2022_0216.to_excel('datacube_period_2022_0216.xlsx')

# Data seems correct

# %% [markdown]
# ## 5. Generate Output DFs

# %%
'''# Create one excel file for each date in datacube_period and save in folder
dates = datacube_period['date'].dt.date.unique()
for date in dates:
    datacube_period_date = datacube_period[datacube_period['date'].dt.date == date]
    datacube_period_date.to_excel(f'datacube_period_{date}.xlsx')
    '''
# Out:
# "# Create one excel file for each date in datacube_period and save in folder\ndates = datacube_period['date'].dt.date.unique()\nfor date in dates:\n    datacube_period_date = datacube_period[datacube_period['date'].dt.date == date]\n    datacube_period_date.to_excel(f'datacube_period_{date}.xlsx')\n    "

# %%
'''# Create one txt file per date by adding all speech content and save
dates = datacube_period['date'].dt.date.unique()

for date in dates:
    # Filter data for each date
    datacube_period_date = datacube_period[datacube_period['date'].dt.date == date]
    
    # Concatenate all speech content into a single string (no separator)
    speech_content_combined = ''.join(datacube_period_date['speech_content'].tolist())
    
    # Write the concatenated speech content to a file
    with open(f'datacube_period_{date}.txt', 'w') as f:
        f.write(speech_content_combined)'''
# Out:
# "# Create one txt file per date by adding all speech content and save\ndates = datacube_period['date'].dt.date.unique()\n\nfor date in dates:\n    # Filter data for each date\n    datacube_period_date = datacube_period[datacube_period['date'].dt.date == date]\n    \n    # Concatenate all speech content into a single string (no separator)\n    speech_content_combined = ''.join(datacube_period_date['speech_content'].tolist())\n    \n    # Write the concatenated speech content to a file\n    with open(f'datacube_period_{date}.txt', 'w') as f:\n        f.write(speech_content_combined)"

# %% [markdown]
# ## 5.1 Final DF for labels

# %%
label_datacube = datacube_period.copy()

#Fill NaN values in speaker_id with 0
label_datacube['politician_id'] = label_datacube['politician_id'].fillna(0)

# Get rid of the .0 in the politician_id
label_datacube['politician_id'] = label_datacube['politician_id'].astype(int)

# Filter out position_long Presidium of Parliament
label_datacube = label_datacube[label_datacube['position_short'] != 'Presidium of Parliament']


# Create one unique identifier for each speaker by adding electoral term, session, and politician_id
label_datacube['speech_id_long'] = label_datacube['electoral_term'].astype(str) + '_' + label_datacube['session'].astype(str) + '_' + label_datacube['politician_id'].astype(str)
label_datacube.tail(10)


# split the speech content by paragraph
label_datacube['speech_content'] = label_datacube['speech_content'].str.split(r'\(\{\d+\}\)')
datacube_period_speaker_exploded = label_datacube.explode('speech_content')

# Filter out everything with less than 200 characters
datacube_period_speaker_exploded = datacube_period_speaker_exploded[datacube_period_speaker_exploded['speech_content'].str.len() > 200]

# Add to the speech_id_long the paragraph number as int
datacube_period_speaker_exploded['speech_id_long'] = datacube_period_speaker_exploded['speech_id_long'] + '_' + datacube_period_speaker_exploded.groupby(['date', 'electoral_term', 'session', 'politician_id', 'ui', 'first_name_x', 'last_name_x']).cumcount().astype(str)

# remove.0 from speech_id_long
datacube_period_speaker_exploded['speech_id_long'] = datacube_period_speaker_exploded['speech_id_long'].str.replace('.0', '')

datacube_period_speaker_exploded.head()
# Out:
#            id  electoral_term  session first_name_x last_name_x  faction_id_x  \
# 32733  729755              17        4                   becker             8
# 32733  729755              17        4                   becker             8
# 32733  729755              17        4                   becker             8
# 32733  729755              17        4                   becker             8
# 32733  729755              17        4                   becker             8
#
#        politician_id          ui position_short              position_long  \
# 32733       11000130  11000130.0       Minister  bundesminister des innern
# 32733       11000130  11000130.0       Minister  bundesminister des innern
# 32733       11000130  11000130.0       Minister  bundesminister des innern
# 32733       11000130  11000130.0       Minister  bundesminister des innern
# 32733       11000130  11000130.0       Minister  bundesminister des innern
#
#                                           speech_content                date  \
# 32733  \nSehr geehrter Herr Präsident! Meine sehr ver... 2009-11-10 22:00:00
# 32733  \n\nMein Verständnis ist, dass der Bundesminis... 2009-11-10 22:00:00
# 32733  \n\nIch kann und will nun nicht den ganzen Zus... 2009-11-10 22:00:00
# 32733  \n\nInnere Sicherheit des Einzelnen ist eigent... 2009-11-10 22:00:00
# 32733  \n\nWer frei in Verantwortung handelt, soll si... 2009-11-10 22:00:00
#
#         speech_id_long
# 32733  17_4_11000130_0
# 32733  17_4_11000130_1
# 32733  17_4_11000130_2
# 32733  17_4_11000130_3
# 32733  17_4_11000130_4

# %%
# Create excel for one date
datacube_period_speaker_exploded[datacube_period_speaker_exploded['date'] == '2022-02-16'].to_excel('datacube_period_speaker_exploded_2022_0216.xlsx')

# %%
len(datacube_period_speaker_exploded)

# Show only columnn speech_content and speech_id_long
final_df_for_labels = datacube_period_speaker_exploded[['speech_content', 'speech_id_long']]
final_df_for_labels.head(10)

# safe as csv
final_df_for_labels.to_pickle('final_df_for_labels_v2.pkl')
